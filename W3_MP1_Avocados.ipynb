# %% [markdown]
# # Week 3 Mini-Project: Avocados

# %%
# Just to ignore warnings

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Download the Dataset
#
# Download the dataset from the following link: \
# https://www.kaggle.com/neuromusic/avocado-prices/

# %% [markdown]
# # 2. Read the Dataset
#
# Read the dataset into a Pandas Dataframe.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv('avocado.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %% [markdown]
# Does the dataset include any missing values? If so, drop them. \
# Hint: Pandas can do that with one line of code!

# %%
df.dropna()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %% [markdown]
# # 3. Extract Features
#
# Exclude the region and date from the considered features.

# %%
df.drop(['Unnamed: 0', 'Date', 'region'], axis = 1, inplace = True)
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags          type  year
# 0         8603.62       93.25          0.0  conventional  2015
# 1         9408.07       97.49          0.0  conventional  2015
# 2         8042.21      103.14          0.0  conventional  2015
# 3         5677.40      133.76          0.0  conventional  2015
# 4         5986.26      197.69          0.0  conventional  2015
# ...           ...         ...          ...           ...   ...
# 18244    13066.82      431.85          0.0       organic  2018
# 18245     8940.04      324.80          0.0       organic  2018
# 18246     9351.80       42.31          0.0       organic  2018
# 18247    10919.54       50.00          0.0       organic  2018
# 18248    11988.14       26.01          0.0       organic  2018
#
# [18249 rows x 11 columns]

# %% [markdown]
# # 4. Perform Preprocessing
#
# Perform any needed pre-processing on the chosen features including: \
# • Scaling; \
# • Encoding; and \
# • Dealing with Nan values. \
# Hint: \
# Use only the preprocessing steps for this mini project.

# %%
from sklearn.preprocessing import LabelEncoder
df.type = LabelEncoder().fit_transform(df.type)

# %%
df
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  year
# 0         8603.62       93.25          0.0     0  2015
# 1         9408.07       97.49          0.0     0  2015
# 2         8042.21      103.14          0.0     0  2015
# 3         5677.40      133.76          0.0     0  2015
# 4         5986.26      197.69          0.0     0  2015
# ...           ...         ...          ...   ...   ...
# 18244    13066.82      431.85          0.0     1  2018
# 18245     8940.04      324.80          0.0     1  2018
# 18246     9351.80       42.31          0.0     1  2018
# 18247    10919.54       50.00          0.0     1  2018
# 18248    11988.14       26.01          0.0     1  2018
#
# [18249 rows x 11 columns]

# %%
# assign attributues to X and y variables
y = df.AveragePrice.values

features = len(df.columns)
X = df.iloc[:, 1:features].values
X
# Out:
# array([[6.4236620e+04, 1.0367400e+03, 5.4454850e+04, ..., 0.0000000e+00,
#         0.0000000e+00, 2.0150000e+03],
#        [5.4876980e+04, 6.7428000e+02, 4.4638810e+04, ..., 0.0000000e+00,
#         0.0000000e+00, 2.0150000e+03],
#        [1.1822022e+05, 7.9470000e+02, 1.0914967e+05, ..., 0.0000000e+00,
#         0.0000000e+00, 2.0150000e+03],
#        ...,
#        [1.3766760e+04, 1.1919200e+03, 2.4527900e+03, ..., 0.0000000e+00,
#         1.0000000e+00, 2.0180000e+03],
#        [1.6205220e+04, 1.5276300e+03, 2.9810400e+03, ..., 0.0000000e+00,
#         1.0000000e+00, 2.0180000e+03],
#        [1.7489580e+04, 2.8947700e+03, 2.3561300e+03, ..., 0.0000000e+00,
#         1.0000000e+00, 2.0180000e+03]])

# %%
from sklearn.preprocessing import StandardScaler

X_scaled = StandardScaler().fit_transform(X)

# %% [markdown]
# # 5. Split the Data
#
# Split your data as follows: \
# • 80% training set \
# • 10% validation set \
# • 10% test set

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.2, random_state = 0)
print(len(X_train), len(X_test))
# Out:
# 14599 3650

# %%
X_validate, X_test, y_validate, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=0)
print(len(X_train), len(X_test), len(X_validate))
# Out:
# 14599 1825 1825

# %% [markdown]
# # 6. Train KNN Regression
#
# Use a KNN regressor model to train your data.

# %%
from sklearn.neighbors import KNeighborsRegressor
# Choose value of K
K=4
model=KNeighborsRegressor(n_neighbors=K)
model.fit(X_train, y_train)
    
score = model.score(X_test,y_test)
print(score)
# Out:
# 0.7501093448112197

# %% [markdown]
# Choose the best k for the KNN algorithm by trying different values and validating performance on the validation set.

# %%
scores = []
score = 0
best_score = 0

K = range(1,15)

for i in K:
    modelKNN = KNeighborsRegressor(n_neighbors = i).fit(X_train, y_train)
    
    score = modelKNN.score(X_test, y_test)
    score = round(score,2)
    scores.append(score)
    
    # Optionally we can run the below code instead
    if score > best_score :
        best_score = score
        bestK = i
        best_model = modelKNN # key advantage to the below code is saving the model
    
    print(i, "gives a score of:", score)
    
best_score = max(scores)
bestK = scores.index(best_score) + 1

print("KNN Regression gives a score of:", best_score, "with", bestK, "neighbors.")
# Out:
# 1 gives a score of: 0.64
# 2 gives a score of: 0.72
# 3 gives a score of: 0.74
# 4 gives a score of: 0.75
# 5 gives a score of: 0.75
# 6 gives a score of: 0.74
# 7 gives a score of: 0.74
# 8 gives a score of: 0.74
# 9 gives a score of: 0.73
# 10 gives a score of: 0.73
# 11 gives a score of: 0.73
# 12 gives a score of: 0.73
# 13 gives a score of: 0.72
# 14 gives a score of: 0.72
# KNN Regression gives a score of: 0.75 with 4 neighbors.

# %%
plt.plot(K,scores)

for i in K :
    plt.annotate(scores[i-1], xy=(i, scores[i-1]), xytext=(i+0.06, scores[i-1]+0.005))

# %%
# Using the best model n_neighbors = 4
# best_model = KNeighborsRegressor(n_neighbors = 4).fit(X_train, y_train)

# Alternatively using the best_model acquired from the if statement
accuracy = best_model.score(X_validate, y_validate)
print('Accuracy of the best model = ', round(accuracy,2))
# Out:
# Accuracy of the best model =  0.75

# %% [markdown]
# # Regression Metrics
# Print the R-squared score of your final KNN regressor.

# %%
y_pred = best_model.predict(X_test)

from sklearn.metrics import r2_score
print('R-squared score of the final KNN regressor = ' + str(r2_score(y_test,y_pred)))
# Out:
# R-squared score of the final KNN regressor = 0.7501093448112197

# %% [markdown]
# # 7. Challenge Yourself (Optional)
# Repeat step 6 for a different regression modelling technique.

# %%
# Using SVM

from sklearn.svm import SVR
    
modelSVM = SVR(C=1.0, kernel='rbf', gamma='auto')
modelSVM.fit(X_train, y_train)

y_pred = modelSVM.predict(X_test)
    
score=modelSVM.score(X_test,y_test)

print('R-squared score of the SVM regressor = ' + str(r2_score(y_test,y_pred)))
print('Accuracy with SVM regression = ', round(score,2))
# Out:
# R-squared score of the SVM regressor = 0.5097871648913239
# Accuracy with SVM regression =  0.51

# %%
# Decision Tree

from sklearn.tree import DecisionTreeRegressor

modelTree = DecisionTreeRegressor().fit(X_train, y_train)

y_pred = modelTree.predict(X_test)

score = modelTree.score(X_test, y_test)

print('R-squared score of the Decision Tree regressor = ' + str(r2_score(y_test,y_pred)))
print("Accuracy with Decision Tree = ", round(score,2))
# Out:
# R-squared score of the Decision Tree regressor = 0.6061581883270373
# Accuracy with Decision Tree =  0.61
